# %% [markdown]
# # Prediction Diabetes in ICU Patients
#
# Author:
# 1. Charis Hadi Febrianto
# 2. Ratu Muthmainah
# 3. Selmareta Nurani
#
# Dataset:
# WiDS Datathon 2021

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score,f1_score,accuracy_score,recall_score

# %% [markdown]
# ## Data Extraction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/TrainingWiDS2021.csv')
data.head()
# Out:
#    Unnamed: 0  encounter_id  ...  solid_tumor_with_metastasis  diabetes_mellitus
# 0           1        214826  ...                            0                  1
# 1           2        246060  ...                            0                  1
# 2           3        276985  ...                            0                  0
# 3           4        262220  ...                            0                  0
# 4           5        201746  ...                            0                  0
#
# [5 rows x 181 columns]

# %%
m = data.shape[0]
n = data.shape[1]

print("Number of rows: " + str(m))
print("Number of colums: " + str(n))
# Out:
# Number of rows: 130157
# Number of colums: 181

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130157 entries, 0 to 130156
# Columns: 181 entries, Unnamed: 0 to diabetes_mellitus
# dtypes: float64(157), int64(18), object(6)
# memory usage: 179.7+ MB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         Unnamed: 0  ...  diabetes_mellitus
# 0                1  ...                  1
# 1                2  ...                  1
# 2                3  ...                  0
# 3                4  ...                  0
# 4                5  ...                  0
# ...            ...  ...                ...
# 130152      130153  ...                  0
# 130153      130154  ...                  0
# 130154      130155  ...                  1
# 130155      130156  ...                  0
# 130156      130157  ...                  0
#
# [130157 rows x 181 columns]>

# %%
data.dtypes.value_counts()
# Out:
# float64    157
# int64       18
# object       6
# dtype: int64

# %%
data.dtypes
# Out:
# Unnamed: 0                       int64
# encounter_id                     int64
# hospital_id                      int64
# age                            float64
# bmi                            float64
#                                 ...
# immunosuppression                int64
# leukemia                         int64
# lymphoma                         int64
# solid_tumor_with_metastasis      int64
# diabetes_mellitus                int64
# Length: 181, dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
# drop kolom yang tidak diperlukan
data = data.drop(columns=['Unnamed: 0',	'encounter_id'])

# %% [markdown]
# ## Data Preprocessing

# %%
# melakukan onne-hot-encoding
data = pd.get_dummies(data)
data.head()
# Out:
#    hospital_id   age  ...  icu_type_Neuro ICU  icu_type_SICU
# 0          118  68.0  ...                   0              0
# 1           81  77.0  ...                   0              0
# 2          118  25.0  ...                   0              0
# 3          118  81.0  ...                   0              0
# 4           33  19.0  ...                   0              0
#
# [5 rows x 212 columns]

# %%
# mencari missing values
data.isnull().sum()
# Out:
# hospital_id                 0
# age                      4988
# bmi                      4490
# elective_surgery            0
# height                   2077
#                          ...
# icu_type_Cardiac ICU        0
# icu_type_MICU               0
# icu_type_Med-Surg ICU       0
# icu_type_Neuro ICU          0
# icu_type_SICU               0
# Length: 212, dtype: int64

# %%
# mengisi values pada kolom age
data['age'].fillna(data['age'].mean(), inplace=True)
data.head()
# Out:
#    hospital_id   age  ...  icu_type_Neuro ICU  icu_type_SICU
# 0          118  68.0  ...                   0              0
# 1           81  77.0  ...                   0              0
# 2          118  25.0  ...                   0              0
# 3          118  81.0  ...                   0              0
# 4           33  19.0  ...                   0              0
#
# [5 rows x 212 columns]

# %%
# mengisi values pada kolom bmi
data['bmi'].fillna(data['bmi'].mean(), inplace=True)
data.head()
# Out:
#    hospital_id   age  ...  icu_type_Neuro ICU  icu_type_SICU
# 0          118  68.0  ...                   0              0
# 1           81  77.0  ...                   0              0
# 2          118  25.0  ...                   0              0
# 3          118  81.0  ...                   0              0
# 4           33  19.0  ...                   0              0
#
# [5 rows x 212 columns]

# %%
# mengisi values pada kolom height
data['height'].fillna(data['height'].mean(), inplace=True)
data.head()
# Out:
#    hospital_id   age  ...  icu_type_Neuro ICU  icu_type_SICU
# 0          118  68.0  ...                   0              0
# 1           81  77.0  ...                   0              0
# 2          118  25.0  ...                   0              0
# 3          118  81.0  ...                   0              0
# 4           33  19.0  ...                   0              0
#
# [5 rows x 212 columns]

# %%
data.isnull().sum()
# Out:
# hospital_id              0
# age                      0
# bmi                      0
# elective_surgery         0
# height                   0
#                         ..
# icu_type_Cardiac ICU     0
# icu_type_MICU            0
# icu_type_Med-Surg ICU    0
# icu_type_Neuro ICU       0
# icu_type_SICU            0
# Length: 212, dtype: int64

# %%
# mengetahui data duplikat 
data.duplicated().sum()
# Out:
# 8

# %%
# menghapus data duplikat
data = data.drop_duplicates()
data.head()
# Out:
#    hospital_id   age  ...  icu_type_Neuro ICU  icu_type_SICU
# 0          118  68.0  ...                   0              0
# 1           81  77.0  ...                   0              0
# 2          118  25.0  ...                   0              0
# 3          118  81.0  ...                   0              0
# 4           33  19.0  ...                   0              0
#
# [5 rows x 212 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.fillna(data.mean(), inplace=True)
data.head()
# Out:
#    hospital_id   age  ...  icu_type_Neuro ICU  icu_type_SICU
# 0          118  68.0  ...                   0              0
# 1           81  77.0  ...                   0              0
# 2          118  25.0  ...                   0              0
# 3          118  81.0  ...                   0              0
# 4           33  19.0  ...                   0              0
#
# [5 rows x 212 columns]

# %%
data.columns[172]
# Out:
# 'diabetes_mellitus'

# %%
plt.figure(figsize=(25,7))
sns.countplot(x='age',hue='diabetes_mellitus',data=data,palette='Set1')

# %%
data = data.values
data
# Out:
# array([[118.        ,  68.        ,  22.73280282, ...,   0.        ,
#           0.        ,   0.        ],
#        [ 81.        ,  77.        ,  27.421875  , ...,   1.        ,
#           0.        ,   0.        ],
#        [118.        ,  25.        ,  31.95274882, ...,   1.        ,
#           0.        ,   0.        ],
#        ...,
#        [  7.        ,  73.        ,  32.26537065, ...,   0.        ,
#           0.        ,   0.        ],
#        [170.        ,  81.        ,  24.40857925, ...,   1.        ,
#           0.        ,   0.        ],
#        [  7.        ,  35.        ,  30.13235818, ...,   0.        ,
#           0.        ,   0.        ]])

# %%
# df.loc([:], ["diabetes_mellitus"])

# %%
# Kolom ke-1 sampai 172 dijadikan sebagai atribut
X = data[:, 0:171]
# Kolom 173 sebagai label
y = data[:, 172]

# %%
# normalisasi
# scaler = StandardScaler()
# scaler.fit(X)
# scaled_data = scaler.transform(X)
# scaled_data = pd.DataFrame(scaled_data, columns=X.columns)
# scaled_data.head()

# %%
# normalisasi
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.57635468, 0.76404494, 0.14891198, ..., 0.        , 0.        ,
#         0.        ],
#        [0.39408867, 0.86516854, 0.23743504, ..., 0.        , 0.        ,
#         0.        ],
#        [0.57635468, 0.28089888, 0.32297154, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.02955665, 0.82022472, 0.3288734 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.83251232, 0.91011236, 0.18054827, ..., 0.        , 0.        ,
#         0.        ],
#        [0.02955665, 0.39325843, 0.28860513, ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# ## Data Split

# %%
# train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.3, random_state=1)

# %% [markdown]
# ## Import RandomForestClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_jobs = 2, random_state = 0)
# Training the classifier
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=2, random_state=0)

# %% [markdown]
# ## Predict Model

# %%
# Applying train classifier to the test
clf.predict(X_test)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ## Viewing the predicted probabilities of the first 10 observations

# %%
clf.predict_proba(X_test)[0:10]
# Out:
# array([[0.79, 0.21],
#        [0.94, 0.06],
#        [0.99, 0.01],
#        [1.  , 0.  ],
#        [0.5 , 0.5 ],
#        [0.87, 0.13],
#        [0.89, 0.11],
#        [0.94, 0.06],
#        [0.49, 0.51],
#        [0.93, 0.07]])

# %% [markdown]
# ## Mapping 0's and 1's for each predicted Diabetes class

# %%
preds = clf.predict(X_test)
preds[0:5]
# Out:
# array([0., 0., 0., 0., 0.])

# %%
# membuat prediksi
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.95      0.89     30586
#          1.0       0.67      0.35      0.46      8459
#
#     accuracy                           0.82     39045
#    macro avg       0.75      0.65      0.68     39045
# weighted avg       0.80      0.82      0.80     39045

# %%
# membuat akurasi
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8212063004225894
